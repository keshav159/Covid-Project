# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dt = pd.read_csv(r"E:\DATA ANALYSIS PROJECTS\Covid Eureka\covid_19_india.csv")

# %%
dt.tail(5)
# Out:
#        Sno Date Time State/UnionTerritory ConfirmedIndianNational  \
# 15109  NaN  NaN  NaN                  NaN                     NaN
# 15110  NaN  NaN  NaN                  NaN                     NaN
# 15111  NaN  NaN  NaN                  NaN                     NaN
# 15112  NaN  NaN  NaN                  NaN                     NaN
# 15113  NaN  NaN  NaN                  NaN                     NaN
#
#       ConfirmedForeignNational  Cured  Deaths  Confirmed
# 15109                      NaN    NaN     NaN        NaN
# 15110                      NaN    NaN     NaN        NaN
# 15111                      NaN    NaN     NaN        NaN
# 15112                      NaN    NaN     NaN        NaN
# 15113                      NaN    NaN     NaN        NaN

# %%
dt.columns
# Out:
# Index(['Sno', 'Date', 'Time', 'State/UnionTerritory',
#        'ConfirmedIndianNational', 'ConfirmedForeignNational', 'Cured',
#        'Deaths', 'Confirmed'],
#       dtype='object')

# %%
dt.describe()
# Out:
#                 Sno         Cured        Deaths     Confirmed
# count  15086.000000  1.508600e+04  15086.000000  1.508600e+04
# mean    7543.500000  1.747937e+05   2721.084449  1.942820e+05
# std     4355.097416  3.648330e+05   7182.672358  4.095184e+05
# min        1.000000  0.000000e+00      0.000000  0.000000e+00
# 25%     3772.250000  1.685000e+03     12.000000  2.935500e+03
# 50%     7543.500000  1.964700e+04    364.000000  2.608150e+04
# 75%    11314.750000  2.087552e+05   2170.000000  2.216012e+05
# max    15086.000000  4.927480e+06  83777.000000  5.433506e+06

# %%
dt.isnull().sum()
# Out:
# Sno                         28
# Date                        28
# Time                        28
# State/UnionTerritory        28
# ConfirmedIndianNational     28
# ConfirmedForeignNational    28
# Cured                       28
# Deaths                      28
# Confirmed                   28
# dtype: int64

# %%
dt = dt.dropna()

# %%
dt.isnull().sum()
# Out:
# Sno                         0
# Date                        0
# Time                        0
# State/UnionTerritory        0
# ConfirmedIndianNational     0
# ConfirmedForeignNational    0
# Cured                       0
# Deaths                      0
# Confirmed                   0
# dtype: int64

# %%
dt = dt.dropna(how='all')

# %%
dt.isnull().sum()
# Out:
# Sno                         0
# Date                        0
# Time                        0
# State/UnionTerritory        0
# ConfirmedIndianNational     0
# ConfirmedForeignNational    0
# Cured                       0
# Deaths                      0
# Confirmed                   0
# dtype: int64

# %%
dt.columns
# Out:
# Index(['Sno', 'Date', 'Time', 'State/UnionTerritory',
#        'ConfirmedIndianNational', 'ConfirmedForeignNational', 'Cured',
#        'Deaths', 'Confirmed'],
#       dtype='object')

# %% [markdown]
# # Relation the variables with scatterplots

# %%
sns.relplot(x="Confirmed",y="Cured",data=dt)

# %%
sns.relplot(x="Confirmed",y="Deaths",data=dt)

# %%
sns.relplot(x="Confirmed",y="ConfirmedForeignNational",data=dt)

# %%
dt.columns
# Out:
# Index(['Sno', 'Date', 'Time', 'State/UnionTerritory',
#        'ConfirmedIndianNational', 'ConfirmedForeignNational', 'Cured',
#        'Deaths', 'Confirmed'],
#       dtype='object')

# %%
sns.pairplot(dt)

# %%
sns.relplot(x="Confirmed",y="State/UnionTerritory" , data=dt)
